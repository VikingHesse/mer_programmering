# %%
#2 (b)
with open("Provresultat.txt", "a+") as f1:
    sorterat = sorted(open("Provresultat.txt"))
    f1.write("\n")
    for namn in sorterat:
        f1.write(namn)

# %%
#2 (c), inte optimal lösning
A = []
B = []
C = []
D = []
E = []
F = []

with open("Provresultat.txt", "a+") as f1:
    sorterat = sorted(open("Provresultat.txt"))
    f1.write("\n")
    for namn in sorterat:
        poäng = int(namn[-3:])

        if poäng > 60:
            A.append(namn)

        elif poäng > 50:
            B.append(namn)

        elif poäng > 40:
            C.append(namn)

        elif poäng > 30:
            D.append(namn)

        elif poäng > 20:
            E.append(namn)

        else:
            F.append(namn)

    f1.write("F \n")    
    for namn in F:
            f1.write(namn)

    f1.write("E \n")    
    for namn in E:
            f1.write(namn)

    f1.write("D \n")    
    for namn in D:
            f1.write(namn)

    f1.write("C \n")    
    for namn in C:
            f1.write(namn)

    f1.write("B \n")    
    for namn in B:
            f1.write(namn)

    f1.write("A \n")    
    for namn in A:
            f1.write(namn)

# %%
#Har testat sortera i ordning med hjälp av dictionary, fick det att sorteras men inte att delas upp i de olika betygen. Men ville se hur dictionaries fungerade. 
namn_poäng = {}
with open("Provresultat.txt", "a+") as f1:
    sorterat = sorted(open("Provresultat.txt"))
    f1.write("\n")
    for rad in sorterat:
        namn = rad[:-3]
        poäng = int(rad[-3:])
        namn_poäng[namn] = poäng

    sorterad_dict = sorted(namn_poäng.items(), key=lambda x: x[1])

    for namn, poäng in sorterad_dict:

        if poäng > 60:
            f1.write(f"{namn}: {poäng}\n")

        elif poäng > 50:
            f1.write(f"{namn}: {poäng}\n")

        elif poäng > 40:
            f1.write(f"{namn}: {poäng}\n")

        elif poäng > 30:
            f1.write(f"{namn}: {poäng}\n")

        elif poäng > 20:
            f1.write(f"{namn}: {poäng}\n")

        else:
            f1.write(f"{namn}: {poäng}\n")

# %%
import random
kast = 10

for i in range(5):
    ettor = 0
    tvåor = 0
    treor = 0
    fyror = 0
    femmor = 0
    sexor = 0

    for i in range(kast):
        tal = random.randint(1, 6)

        if tal == 1:
            ettor += 1

        elif tal == 2:
            tvåor += 1

        elif tal == 3:
            treor += 1

        elif tal == 4:
            fyror += 1

        elif tal == 5:
            femmor += 1

        elif tal == 6:
            sexor += 1

    sannolikhet_ettor = ettor / kast
    sannolikhet_tvåor = tvåor / kast
    sannolikhet_treor = treor / kast
    sannolikhet_fyror = fyror / kast
    sannolikhet_femmor = femmor / kast
    sannolikhet_sexor = sexor / kast

    with open("simulering.txt", "a+") as f1:
        f1.write(f"\nAntal kast: {kast}\n")
        f1.write(f"Antal ettor: {ettor} Sannolikhet etta: {sannolikhet_ettor}\n")
        f1.write(f"Antal tvåor: {tvåor} Sannolikhet tvåa: {sannolikhet_tvåor}\n")
        f1.write(f"Antal treor: {treor} Sannolikhet trea: {sannolikhet_treor}\n")
        f1.write(f"Antal fyror: {fyror} Sannolikhet fyra: {sannolikhet_fyror}\n")
        f1.write(f"Antal femmor: {femmor} Sannolikhet femma: {sannolikhet_femmor}\n")
        f1.write(f"Antal sexor: {sexor} Sannolikhet sexa: {sannolikhet_sexor}\n")

    kast *= 10
