# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    y = x**2 - 1
    return y

x = np.linspace(-2,2)

plt.xlabel("x")
plt.ylabel("y")
plt.title("f(x) = x^2 -1")
plt.plot(x, f(x))
plt.show()
